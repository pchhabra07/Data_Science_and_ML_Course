# %% [markdown]
# ## PCA Implementation using SK Learn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
data = {
    'Height':[150,160,170,180,190],
    'Weight':[50,60,65,80,90],
    'Age':[20,25,30,35,40]
}

df = pd.DataFrame(data)

print("Original Data")
print(df)
# Out:
# Original Data
#    Height  Weight  Age
# 0     150      50   20
# 1     160      60   25
# 2     170      65   30
# 3     180      80   35
# 4     190      90   40

# %%
scaler = StandardScaler()

scaled_data = scaler.fit_transform(df)

print("Scaled Data")
print(scaled_data)
# Out:
# Scaled Data
# [[-1.41421356 -1.33026608 -1.41421356]
#  [-0.70710678 -0.63012604 -0.70710678]
#  [ 0.         -0.28005602  0.        ]
#  [ 0.70710678  0.77015405  0.70710678]
#  [ 1.41421356  1.47029409  1.41421356]]

# %%
pca = PCA(n_components=2)

principal_components = pca.fit_transform(scaled_data)

print("Principal Components")
print(principal_components)
# Out:
# Principal Components
# [[-2.40112677  0.06479274]
#  [-1.18039675  0.061011  ]
#  [-0.16133308 -0.22891704]
#  [ 1.26106329  0.05344752]
#  [ 2.48179331  0.04966577]]

# %%
pca_df = pd.DataFrame(principal_components,
                      columns=['PC1','PC2'])

print(pca_df)
# Out:
#         PC1       PC2
# 0 -2.401127  0.064793
# 1 -1.180397  0.061011
# 2 -0.161333 -0.228917
# 3  1.261063  0.053448
# 4  2.481793  0.049666

# %%
pca = PCA(n_components=2)

principal_components = pca.fit_transform(scaled_data)

print("Principal Components")
print(principal_components)
# Out:
# Principal Components
# [[-2.40112677  0.06479274]
#  [-1.18039675  0.061011  ]
#  [-0.16133308 -0.22891704]
#  [ 1.26106329  0.05344752]
#  [ 2.48179331  0.04966577]]

# %%
print("Explained Variance Ratio:")
print(pca.explained_variance_ratio_)
# Out:
# Explained Variance Ratio:
# [0.99562355 0.00437645]

# %%
plt.figure(figsize=(6,6))

plt.scatter(pca_df['PC1'], pca_df['PC2'])

plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA Visualization")
# Out:
# Text(0.5, 1.0, 'PCA Visualization')

# %%
print("PCA Components")

print(pca.components_)
# Out:
# PCA Components
# [[ 0.57798718  0.57607433  0.57798718]
#  [-0.40734607  0.81739731 -0.40734607]]
