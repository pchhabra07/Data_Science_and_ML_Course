# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
#This is a comment
print("Hello, World!")
# Out:
# Hello, World!

# %%
"""
This is a comment
written in
more than just one line
"""
print("Hello, World!")
# Out:
# Hello, World!

# %%
x = 6
y = "Aryesh rai"
print(x)
print(y)
# Out:
# 6
# Aryesh rai

# %%
x = 4       # x is of type int
x = "India" # x is now of type str
print(x)
# Out:
# India

# %%
x = str(3)    # x will be '3'
y = int(3)    # y will be 3
z = float(3)  # z will be 3.0
print(type(x))
print(type(y))
print(type(z))
print(x)
print(y)
print(z)
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# 3
# 3
# 3.0

# %%
x = "Aryesh"
# is the same as
x = 'Aryesh'

# %%
myvar = "India"
my_var = "India"
_my_var = "India"
myVar = "India"
MYVAR = "India"
myvar2 = "India"

# %%
2myvar = "India"
# Out:
#   File "/tmp/ipykernel_867/3679499105.py", line 1
#     2myvar = "India"
#     ^
# SyntaxError: invalid decimal literal

# %%
my-var = "India"

# %%
my var = "India"

# %%
x, y, z = "Virat", "Rohit", "Hardik"
print(x)
print(y)
print(z)

# %%
x = y = z = "India"
print(x)
print(y)
print(z)

# %%
India = ["Virat", "Rohit", "Hardik"]
x, y, z = India
print(x)
print(y)
print(z)

# %%
India = ["Virat", "Rohit"]
x, y, z = India
print(x)
print(y)
print(z)

# %%
x = "Python"
y = "is"
z = "awesome"
print(x, y, z)

# %%
x = "Python"
y = "is"
z = "awesome"
print(x + y + z)

# %%
x = 5
y = 10
print(x + y)
# Out:
# 15

# %%
x = 105
y = "Aryesh"
print(x + y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_867/2352535391.py in <cell line: 0>()
#       1 x = 105
#       2 y = "Aryesh"
# ----> 3 print(x + y)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
x = 105
y = "Aryesh"
print(x, y)

# %%
x = "5"
y = 10
print(int(x) + y)

# %%
x = int(10)   # x will be 10
y = int(2.8) # y will be 2
z = int("3") # z will be 3
print(x)
print(y)
print(z)
# Out:
# 10
# 2
# 3

# %%
x = float(1)     # x will be 1.0
y = float(2.8)   # y will be 2.8
z = float("3")   # z will be 3.0

print(x)
print(y)
print(z)
# Out:
# 1.0
# 2.8
# 3.0

# %%
x = str("Aryesh") # x will be "Aryesh"
y = str(20)    # y will be '20'
z = str(3.0)  # z will be '3.0'
print(x)
print(y)
print(z)
# Out:
# Aryesh
# 20
# 3.0

# %%
print("Hello")
print('Hello')
# Out:
# Hello
# Hello

# %%
b = "Hello, World!"
print(b[2:5])
# Out:
# llo

# %%
b = "Hello, World!"
print(b[1:1])

# %%
b = "Hello, World!"
print(b[:5])
# Out:
# Hello

# %%
b = "Hello, World!"
print(b[2:])
# Out:
# llo, World!

# %%
b = "Hello, World!"
print(b[-5:-2])
# Out:
# orl

# %%
a = "Hello, World!"
print(a.upper())
# Out:
# HELLO, WORLD!

# %%
a = "Hello, World!"
print(a.lower())
# Out:
# hello, world!

# %%
a = " Hello, World! "
print(a.strip())
# Out:
# Hello, World!

# %%
a = "Hello, WorHd!"
print(a.replace("H", "J"))
# Out:
# Jello, WorJd!

# %%
a = "Hello"
b = "World"
c = a + b
print(c)
# Out:
# HelloWorld

# %%
a = "Hello"
b = "World"
c = a + " " + b
print(c)
# Out:
# Hello World

# %%
print(10 > 9)
print(10 == 9)
print(10 < 9)
# Out:
# True
# False
# False

# %%
print(bool("Hello"))
print(bool(15))
# Out:
# True
# True

# %%
bool("abc")
bool(123)
bool(["apple", "cherry", "banana"])
# Out:
# True

# %%
bool(False)
bool(None)
bool(0)
bool("")
bool(())
bool([])
bool({})
# Out:
# False

# %%
x = 14
y = 5

print(x / y)
# Out:
# 2.8

# %%
x = 14
y = 5

print(x // y)
# Out:
# 2

# %%
x = 15
y = 13

print(x == y)
print(x != y)
print(x > y)
print(x < y)
print(x >= y)
print(x <= y)
# Out:
# False
# True
# True
# False
# True
# False

# %%
x = 7

print(1 < x < 10)

print(1 < x and x < 10)
# Out:
# True
# True

# %%
x = 6

print(x < 5 or x > 10)
# Out:
# False

# %%
x = ["apple", "banana"]
y = ["apple", "banana"]
z = x

print(x is z)
print(x is y)
print(x == y)
# Out:
# True
# False
# True

# %%
x = ["apple", "banana"]
y = ["apple", "banana"]

print(x is not y)
# Out:
# True

# %%
x = [1, 2, 3]
y = [1, 2, 3]

print(x == y)
print(x is y)
# Out:
# True
# False

# %%
fruits = ["apple", "banana", "cherry"]

print("banana" in fruits)
# Out:
# True

# %%
fruits = ["apple", "banana", "cherry"]

print("pineapple"  in fruits)
# Out:
# False

# %%
fruits = ["apple", "banana", "cherry"]

print("pineapple" not in fruits)
# Out:
# True

# %%
text = "Hello World"

print("H" in text)
print("hello" in text)
print("z" not in text)
# Out:
# True
# False
# True

# %%
age = 36

txt = "My name is Ayush, I am " + age
print(txt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_867/308209364.py in <cell line: 0>()
#       1 age = 36
#       2
# ----> 3 txt = "My name is Ayush, I am " + age
#       4 print(txt)
#
# TypeError: can only concatenate str (not "int") to str

# %%
age = 36
txt = f"My name is Ayush, I am {age}"
print(txt)
# Out:
# My name is Ayush, I am 36

# %%
price = 444
txt = f"The cost is {price} rupees"
print(txt)
# Out:
# The cost is 444 rupees

# %%
price = 45
txt = f"The cost is {price:.2f} rupees"
print(txt)
# Out:
# The cost is 45.00 rupees

# %%
txt = f"The cost is {20 * 100} rupees"
print(txt)
# Out:
# The cost is 2000 rupees

# %%
mylist = ["apple", "banana", "cherry"]
print(mylist)
print(type(mylist))
# Out:
# ['apple', 'banana', 'cherry']
# <class 'list'>

# %%
mylist = ["apple", "banana", "cherry", "apple", "cherry"]
print(mylist)
# Out:
# ['apple', 'banana', 'cherry', 'apple', 'cherry']

# %%
mylist = ["apple", "banana", "cherry"]
print(type(mylist))
# Out:
# <class 'list'>

# %%
list1 = ["apple", "banana", "cherry"]
list2 = [1, 5, 7, 9, 3]
list3 = [True, False, False]
print (list1)
print (list2)
print (list3)
# Out:
# ['apple', 'banana', 'cherry']
# [1, 5, 7, 9, 3]
# [True, False, False]

# %%
list1 = ["abc", 34, True, 40, "male"]
print(list1)
# Out:
# ['abc', 34, True, 40, 'male']

# %%
mylist = ["apple", "banana", "cherry"]
print(len(mylist))
# Out:
# 3

# %%
mylist = list(("apple", "banana", "cherry")) # note the double round-brackets
print(mylist)
print(type(mylist))
# Out:
# ['apple', 'banana', 'cherry']
# <class 'list'>

# %%
mylist = ["apple", "banana", "cherry"]
print(mylist[1])
# Out:
# banana

# %%
mylist = ["apple", "banana", "cherry"]
print(mylist[-1])
# Out:
# cherry

# %%
mylist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(mylist[2:5])
# Out:
# ['cherry', 'orange', 'kiwi']

# %%
mylist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(mylist[:4])
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
mylist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(mylist[2:])
# Out:
# ['cherry', 'orange', 'kiwi', 'melon', 'mango']

# %%
mylist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(mylist[-4:-1])
# Out:
# ['orange', 'kiwi', 'melon']

# %%
mylist = ["apple", "banana", "cherry"]
mylist.insert(2, "watermelon")
print(mylist)
# Out:
# ['apple', 'banana', 'watermelon', 'cherry']

# %%
mylist = ["apple", "banana", "cherry"]
mylist.append("orange")
print(mylist)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
mylist = ["apple", "banana", "cherry"]
mylist.remove("banana")
print(mylist)
# Out:
# ['apple', 'cherry']

# %%
mylist = ["apple", "banana", "cherry", "banana", "kiwi"]
mylist.remove("banana")
print(mylist)
# Out:
# ['apple', 'cherry', 'banana', 'kiwi']

# %%
mylist = ["apple", "banana", "cherry"]
mylist.pop(1)
print(mylist)
# Out:
# ['apple', 'cherry']

# %%
mylist = ["apple", "banana", "cherry"]
mylist.pop()
print(mylist)
# Out:
# ['apple', 'banana']

# %%
mylist = ["apple", "banana", "cherry"]
del mylist[0]
print(mylist)
# Out:
# ['banana', 'cherry']

# %%
mylist = ["apple", "banana", "cherry"]
del mylist
print(mylist)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7160/3638584189.py in <cell line: 0>()
#       1 mylist = ["apple", "banana", "cherry"]
#       2 del mylist
# ----> 3 print(mylist)
#
# NameError: name 'mylist' is not defined

# %%
mylist = ["apple", "banana", "cherry"]
mylist.clear()
print(mylist)
# Out:
# []

# %%
mylist = ["apple", "banana", "cherry"]
for x in mylist:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
mylist = [2, 4, 5]
for x in mylist:
  print(x)
# Out:
# 2
# 4
# 5

# %%
mylist = ["apple", "banana", "cherry"]
for i in range(len(mylist)):
  print(mylist[i])
# Out:
# apple
# banana
# cherry

# %%
mylist = ["orange", "mango", "kiwi", "pineapple", "banana"]
mylist.sort()
print(mylist)
# Out:
# ['banana', 'kiwi', 'mango', 'orange', 'pineapple']

# %%
mylist = [100, 50, 65, 82, 23]
mylist.sort()
print(mylist)
# Out:
# [23, 50, 65, 82, 100]

# %%
mylist = ["orange", "mango", "kiwi", "pineapple", "banana"]
mylist.sort(reverse = True)
print(mylist)
# Out:
# ['pineapple', 'orange', 'mango', 'kiwi', 'banana']

# %%
mylist = [100, 50, 65, 82, 23]
mylist.sort(reverse = True)
print(mylist)
# Out:
# [100, 82, 65, 50, 23]

# %%
list1 = ["apple", "banana"]
list2 = list1
print(list2)
list2.append("cherry")
print(list2)
print(list1)
# Out:
# ['apple', 'banana']
# ['apple', 'banana', 'cherry']
# ['apple', 'banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
mylist = thislist.copy()

print(mylist)
thislist.append("orange")
print(thislist)
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']
# ['apple', 'banana', 'cherry', 'orange']
# ['apple', 'banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
mylist = list(thislist)
print(mylist)
thislist.append("orange")
print(thislist)
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']
# ['apple', 'banana', 'cherry', 'orange']
# ['apple', 'banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
mylist = thislist[:]
print(mylist)
thislist.append("orange")
print(thislist)
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']
# ['apple', 'banana', 'cherry', 'orange']
# ['apple', 'banana', 'cherry']

# %%
list1 = ["a", "b", "c"]
list2 = [1, 2, 3]

list3 = list1 + list2
print(list3)
print(type(list1))
print(type(list2))
# Out:
# ['a', 'b', 'c', 1, 2, 3]
# <class 'list'>
# <class 'list'>

# %% [markdown]
# TUPLE

# %%
mytuple = ("apple", "banana", "cherry")
print(mytuple)
# Out:
# ('apple', 'banana', 'cherry')

# %%
mytuple = ("apple", "banana", "cherry", "apple", "cherry")
print(mytuple)
# Out:
# ('apple', 'banana', 'cherry', 'apple', 'cherry')

# %%
tuple1 = ("apple", "banana", "cherry")
tuple2 = (1, 5, 7, 9, 3)
tuple3 = (True, False, False)

# %%
tuple1 = ("abc", 34, True, 40, "male")

# %%
mytuple = ("apple",)
print(type(mytuple))
# not a tuple
mytuple = ("apple")
print(type(mytuple))
# Out:
# <class 'tuple'>
# <class 'str'>

# %%
mytuple = tuple(("apple", "banana", "cherry")) # note the double round-brackets
print(mytuple)
# Out:
# ('apple', 'banana', 'cherry')

# %%
mytuple = ("apple", "banana", "cherry")
print(mytuple[1])
# Out:
# banana

# %%
mytuple = ("apple", "banana", "cherry")
print(mytuple[-1])
# Out:
# cherry

# %%
mytuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(mytuple[2:5])
# Out:
# ('cherry', 'orange', 'kiwi')

# %%
mytuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(mytuple[-4:-1])
# Out:
# ('orange', 'kiwi', 'melon')

# %%
mytuple = ("apple", "banana", "cherry")
if "apple" in mytuple:
  print("Yes, 'apple' is in the fruits ")
# Out:
# Yes, 'apple' is in the fruits

# %%
x = ("apple", "banana", "cherry")

x[1] = "kiwi"


print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_7160/5851715.py in <cell line: 0>()
#       1 x = ("apple", "banana", "cherry")
#       2
# ----> 3 x[1] = "kiwi"
#       4
#       5
#
# TypeError: 'tuple' object does not support item assignment

# %%
x = ("apple", "banana", "cherry")
y = list(x)

print(type(y))
print(type(x))
y[1] = "kiwi"
x = tuple(y)
print(type(x))

print(x)
# Out:
# <class 'list'>
# <class 'tuple'>
# <class 'tuple'>
# ('apple', 'kiwi', 'cherry')

# %%
mytuple = ("apple", "banana", "cherry")
y = list(mytuple)
y.append("orange")
mytuple = tuple(y)
print(mytuple)
# Out:
# ('apple', 'banana', 'cherry', 'orange')

# %%
thistuple = ("apple", "banana", "cherry")
y = ("orange",)
thistuple += y

print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'orange')

# %%
fruits = ("apple", "banana", "cherry")

(green, yellow, red) = fruits

print(green)
print(yellow)
print(red)
# Out:
# apple
# banana
# cherry

# %%
fruits = ("apple", "banana", "cherry", "strawberry", "raspberry")

(green, yellow, *red) = fruits

print(green)
print(yellow)
print(red)
# Out:
# apple
# banana
# ['cherry', 'strawberry', 'raspberry']

# %%
fruits = ("apple", "mango", "papaya", "pineapple", "cherry")

(green, *tropic, red) = fruits

print(green)
print(tropic)
print(red)
# Out:
# apple
# ['mango', 'papaya', 'pineapple']
# cherry

# %%
mytuple = ("apple", "banana", "cherry")
for x in mytuple:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
mytuple = ("apple", "banana", "cherry")
for i in range(len(mytuple)):
  print(mytuple[i])
# Out:
# apple
# banana
# cherry

# %%
mytuple = ("apple", "banana", "cherry")

print(mytuple[1])
# Out:
# banana

# %%
tuple1 = ("a", "b" , "c")
tuple2 = (1, 2, 3)

tuple3 = tuple1 + tuple2
print(tuple3)
# Out:
# ('a', 'b', 'c', 1, 2, 3)

# %% [markdown]
# Dictionary

# %%
mydict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
print(mydict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
mydict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
print(mydict["brand"])
# Out:
# Ford

# %%
mydict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 2021,
  "8": 2020
}
print(mydict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2021, '8': 2020}

# %%
mydict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964

}
x = mydict["model"]
print(x)
y = mydict.get("model")
print(y)
z =mydict.keys()
print(z)
k= mydict.values()
print(k)
t=mydict.items()
print(t)
# Out:
# Mustang
# Mustang
# dict_keys(['brand', 'model', 'year'])
# dict_values(['Ford', 'Mustang', 1964])
# dict_items([('brand', 'Ford'), ('model', 'Mustang'), ('year', 1964)])

# %%
mydict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964,
  "year": 1964

}

z =mydict.items()
print(z)
# Out:
# dict_items([('brand', 'Ford'), ('model', 'Mustang'), ('year', 1964)])

# %%
mydict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
mydict.pop("model")
print(mydict)
# Out:
# {'brand': 'Ford', 'year': 1964}

# %%
mydict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
mydict.popitem()
print(mydict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang'}

# %%
mydict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
del mydict
print(mydict) #this will cause an error because "thisdict" no longer exists.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7160/2123438370.py in <cell line: 0>()
#       5 }
#       6 del mydict
# ----> 7 print(mydict) #this will cause an error because "thisdict" no longer exists.
#
# NameError: name 'mydict' is not defined

# %%
mydict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
mydict.clear()
print(mydict)
# Out:
# {}

# %%
mydict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
for x in mydict:
  print(x)
for y in mydict:
  print(mydict[y])
for z in mydict.values():
  print(z)
for t in mydict.keys():
  print(t)
for k,v in mydict.items():
  print(k,v)
# Out:
# brand
# model
# year
# Ford
# Mustang
# 1964
# Ford
# Mustang
# 1964
# brand
# model
# year
# brand Ford
# model Mustang
# year 1964

# %%
myfamily = {
  "child1" : {
    "name" : "Emil",
    "year" : 2004
  },
  "child2" : {
    "name" : "Tobias",
    "year" : 2007
  },
  "child3" : {
    "name" : "Linus",
    "year" : 2011
  }
}
print(myfamily)
print(type(myfamily))
# Out:
# {'child1': {'name': 'Emil', 'year': 2004}, 'child2': {'name': 'Tobias', 'year': 2007}, 'child3': {'name': 'Linus', 'year': 2011}}
# <class 'dict'>

# %% [markdown]
# SET

# %%
myset = {"apple", "banana", "cherry"}
print(myset)
# Out:
# {'cherry', 'banana', 'apple'}

# %%
myset = {"apple", "banana", "cherry", "apple"}

print(myset)
# Out:
# {'cherry', 'banana', 'apple'}

# %%
thisset = {"apple", "banana", "cherry"}

for x in thisset:
  print(x)
# Out:
# cherry
# banana
# apple

# %%
myset = {"apple", "banana", "cherry"}
print(type(myset))
# Out:
# <class 'set'>

# %%
thisset = set(("apple", "banana", "cherry")) # note the double round-brackets
print(thisset)
# Out:
# {'cherry', 'banana', 'apple'}

# %%
thisset = {"apple", "banana", "cherry"}

thisset.remove("banana")

print(thisset)
# Out:
# {'cherry', 'apple'}

# %%
thisset = {"apple", "banana", "cherry"}

x = thisset.pop()

print(x)

print(thisset)
# Out:
# cherry
# {'banana', 'apple'}

# %%
thisset = {"apple", "banana", "cherry"}

thisset.clear()

print(thisset)
# Out:
# set()

# %%
thisset = {"apple", "banana", "cherry"}

del thisset

print(thisset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7160/3077915618.py in <cell line: 0>()
#       3 del thisset
#       4
# ----> 5 print(thisset)
#
# NameError: name 'thisset' is not defined

# %%
thisset = {"apple", "banana", "cherry"}

for x in thisset:
  print(x)
# Out:
# cherry
# banana
# apple

# %%
set1 = {"a", "b", "c",}
set2 = {1, 2, 3}

set3 = set1.union(set2)
print(set3)
# Out:
# {'a', 'c', 'b', 1, 2, 3}

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}

set3 = set1 | set2
print(set3)
# Out:
# {'a', 'c', 'b', 1, 2, 3}

# %%
x = frozenset({"apple", "banana", "cherry"})
print(x)

print(type(x))
# Out:
# frozenset({'cherry', 'banana', 'apple'})
# <class 'frozenset'>

# %%
x = frozenset(("apple", "banana", "cherry"))
x.add("orange")
print(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_7160/1821272982.py in <cell line: 0>()
#       1 x = frozenset(("apple", "banana", "cherry"))
# ----> 2 x.add("orange")
#       3 print(x)
#       4
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
x = frozenset({"apple", "banana", "cherry"})
x.remove("apple")
print(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_7160/1685141434.py in <cell line: 0>()
#       1 x = frozenset({"apple", "banana", "cherry"})
# ----> 2 x.remove("apple")
#       3 print(x)
#
# AttributeError: 'frozenset' object has no attribute 'remove'
